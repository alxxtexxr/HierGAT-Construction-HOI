# %% [markdown]
# Conda environment: `py39_torch271`

# %%
import os
import random
from copy import deepcopy

from typing import Optional
from dataclasses import dataclass, asdict
from pathlib import Path
from datetime import datetime

import torch
import numpy as np
import pandas as pd
from dacite import from_dict
from sklearn.model_selection import train_test_split

from pyrutils.torch.train_utils import train, save_checkpoint
from pyrutils.torch.multi_task import MultiTaskLossLearner
from vhoi.data_loading import (
    input_size_from_data_loader, 
    select_model_data_feeder, 
    select_model_data_fetcher,
)
from vhoi.data_loading_custom import (
    create_data,
    create_data_loader
)
from vhoi.losses_custom_v2 import (
    select_loss, 
    decide_num_main_losses, 
    select_loss_types, 
    select_loss_learning_mask,
)
from vhoi.models import load_model_weights
from vhoi.models_custom_v2 import TGGCN

seed = 42
random.seed(seed)   # Python的随机性
os.environ['PYTHONHASHSEED'] = str(seed)    # 设置Python哈希种子，为了禁止hash随机化，使得实验可复现
np.random.seed(seed)   # numpy的随机性
torch.manual_seed(seed)   # torch的CPU随机性，为CPU设置随机种子
torch.cuda.manual_seed(seed)   # torch的GPU随机性，为当前GPU设置随机种子
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.   torch的GPU随机性，为所有GPU设置随机种子
torch.backends.cudnn.benchmark = False   # if benchmark=True, deterministic will be False
torch.backends.cudnn.deterministic = True   # 选择确定性算法

# %%
class DictMixin:
    def get(self, key, default_value=None):
        return getattr(self, key, default_value)

    def as_dict(self):
        return asdict(self)
    
@dataclass
class Resources(DictMixin):
    use_gpu: bool
    num_threads: int

@dataclass
class ModelMetadata(DictMixin):
    model_name: str
    input_type: str

@dataclass
class ModelParameters(DictMixin):
    add_segment_length: int
    add_time_position: int
    time_position_strategy: str
    positional_encoding_style: str
    attention_style: str
    bias: bool
    cat_level_states: int
    discrete_networks_num_layers: int
    discrete_optimization_strategy: str
    filter_discrete_updates: bool
    gcn_node: int
    hidden_size: int
    message_humans_to_human: bool
    message_human_to_objects: bool
    message_objects_to_human: bool
    message_objects_to_object: bool
    message_geometry_to_objects: bool
    message_geometry_to_human: bool
    message_segment: bool
    message_type: str
    message_granularity: str
    message_aggregation: str
    object_segment_update_strategy: str
    share_level_mlps: int
    update_segment_threshold: float

@dataclass
class ModelOptimization(DictMixin):
    batch_size: int
    clip_gradient_at: float
    epochs: int
    learning_rate: float
    val_fraction: float

@dataclass
class BudgetLoss(DictMixin):
    add: bool
    human_weight: float
    object_weight: float

@dataclass
class SegmentationLoss(DictMixin):
    add: bool
    pretrain: bool
    sigma: float
    weight: float

@dataclass
class ModelMisc(DictMixin):
    anticipation_loss_weight: float
    budget_loss: BudgetLoss
    first_level_loss_weight: float
    impose_segmentation_pattern: int
    input_human_segmentation: bool
    input_object_segmentation: bool
    make_attention_distance_based: bool
    multi_task_loss_learner: bool
    pretrained: bool
    pretrained_path: Optional[str]
    segmentation_loss: SegmentationLoss

@dataclass
class ModelLogging(DictMixin):
    root_log_dir: str
    checkpoint_name: str
    log_dir: str

@dataclass
class Models(DictMixin):
    metadata: ModelMetadata
    parameters: ModelParameters
    optimization: ModelOptimization
    misc: ModelMisc
    logging: ModelLogging

@dataclass
class Data(DictMixin):
    name: str
    path: str
    path_zarr: str
    path_obb_zarr: str
    path_hbb_zarr: str
    path_hps_zarr: str
    cross_validation_test_subject: str
    scaling_strategy: Optional[str]
    downsampling: int

@dataclass
class Config(DictMixin):
    resources: Resources
    models: Models
    data: Data
    
metadata_dict = {
    "model_name": "2G-GCN",
    "input_type": "multiple"
}

parameters_dict = {
    "add_segment_length": 0,  # length of the segment to the segment-level rnn. 0 is off and 1 is on.
    "add_time_position": 0,  # absolute time position to the segment-level rnn. 0 is off and 1 is on.
    "time_position_strategy": "s",  # input time position to segment [s] or discrete update [u].
    "positional_encoding_style": "e",  # e [embedding] or p [periodic].
    "attention_style": "v3",  # v1 [concat], v2 [dot-product], v3 [scaled_dot-product], v4 [general]
    "bias": True,
    "cat_level_states": 0,  # concatenate first and second level hidden states for predictors MLPs.
    "discrete_networks_num_layers": 1,  # depth of the state change detector MLP.
    "discrete_optimization_strategy": "gs",  # straight-through [st] or gumbel-sigmoid [gs]
    "filter_discrete_updates": False,  # maxima filter for soft output of state change detector.
    "gcn_node": 25,  # custom, original: 19 for cad120, 30 for bimanual, 26 for mphoi
    "hidden_size": 512,  # 512 for cad120 & mphoi; 64 for bimanual
    "message_humans_to_human": False, # custom, original: True
    "message_human_to_objects": True,
    "message_objects_to_human": True,
    "message_objects_to_object": False, # custom, original: True
    "message_geometry_to_objects": True,
    "message_geometry_to_human": True,  # custom, original: False
    "message_segment": True,
    "message_type": "v2",  # v1 [relational] or v2 [non-relational]
    "message_granularity": "v1",  # v1 [generic] or v2 [specific]
    "message_aggregation": "att",  # mean_pooling [mp] or attention [att]
    "object_segment_update_strategy": "ind",  # same_as_human [sah], independent [ind], or conditional_on_human [coh]
    "share_level_mlps": 0,  # whether to share [1] or not [0] the prediction MLPs of the levels.
    "update_segment_threshold": 0.5  # [0.0, 1.0)
}

optimization_dict = {
    "batch_size": 32,  # mphoi:8; cad120:16; bimanual: 32
    "clip_gradient_at": 0.0,
    "epochs": 10, # custom, original: cad120 & mphoi:40; bimanual: 60
    "learning_rate": 1e-4,  # mphoi:1e-4; cad120 & bimanual:1e-3
    "val_fraction": 0.1
}

data_dict = {
    "name": "mphoi",
    "path": f"{os.getcwd()}/data/MPHOI/MPHOI/mphoi_ground_truth_labels.json",
    "path_zarr": f"{os.getcwd()}/data/MPHOI/MPHOI/mphoi_derived_features/faster_rcnn.zarr",
    "path_obb_zarr": f"{os.getcwd()}/data/MPHOI/MPHOI/mphoi_derived_features/object_bounding_boxes.zarr",
    "path_hbb_zarr": f"{os.getcwd()}/data/MPHOI/MPHOI/mphoi_derived_features/human_bounding_boxes.zarr",
    "path_hps_zarr": f"{os.getcwd()}/data/MPHOI/MPHOI/mphoi_derived_features/human_pose.zarr",
    "cross_validation_test_subject": "Subject14",  # Subject45, Subject25, Subject14
    "scaling_strategy": None,  # null or "standard"
    "downsampling": 1 # custom, original: 3, 1 = full FPS, 2 = half FPS, ...
}

# root_log_dir = f"{os.getcwd()}/outputs_hiergat/{data_dict['name']}/{metadata_dict['model_name']}"
root_log_dir = f"{os.getcwd()}/outputs_hiergat/custom"
checkpoint_name = (
    f"hs{parameters_dict['hidden_size']}_e{optimization_dict['epochs']}_bs{optimization_dict['batch_size']}_"
    f"lr{optimization_dict['learning_rate']}_{parameters_dict['update_segment_threshold']}_{datetime.now().strftime('%Y%m%d%H%M%S')}"
)
log_dir = f"{root_log_dir}/{checkpoint_name}"
print("Log directory:", log_dir)
os.makedirs(log_dir, exist_ok=True)

cfg_dict = {
    "resources": {
        "use_gpu": True,
        "num_threads": 32
    },
    "models": {
        "metadata": metadata_dict,
        "parameters": parameters_dict,
        "optimization": optimization_dict,
        "misc": {
            "anticipation_loss_weight": 1.0,
            "budget_loss": {
                "add": False,
                "human_weight": 1.0,
                "object_weight": 1.0
            },
            "first_level_loss_weight": 0.0,  # if positive, first level does frame-level prediction
            "impose_segmentation_pattern": 1,  # 0 [no pattern], 1 [all ones]
            "input_human_segmentation": False,  # (was "flase" in YAML, corrected here)
            "input_object_segmentation": False,
            "make_attention_distance_based": True,  # only meaningful if message_aggregation is attention
            "multi_task_loss_learner": False,
            "pretrained": False,  # unfortunately need two entries for checkpoint name
            "pretrained_path": None,  # specified parameters must match pre-trained model
            "segmentation_loss": {
                "add": False,
                "pretrain": False,
                "sigma": 0.0,  # Gaussian smoothing
                "weight": 1.0
            }
        },
        "logging": {
            "root_log_dir": root_log_dir,
            "checkpoint_name": checkpoint_name,
            "log_dir": log_dir
        },
    },
    "data": data_dict,
}

cfg = from_dict(data_class=Config, data=cfg_dict)

torch.set_num_threads(cfg.resources.num_threads)
model_name, model_input_type = cfg.models.metadata.model_name, cfg.models.metadata.input_type
batch_size, val_fraction = cfg.models.optimization.batch_size, cfg.models.optimization.val_fraction
misc_dict = cfg.get('misc', default_value={})
sigma = misc_dict.get('segmentation_loss', {}).get('sigma', 0.0)
scaling_strategy = cfg.data.scaling_strategy
downsampling = cfg.data.downsampling

action_classes = [
    # human
    'supervise',        # 0
    'collaborate with', # 1
    'assist',           # 2
    'lead',             # 3
    'coordinate with',  # 4
    'listen to',        # 5

    # rebar
    'tie',              # 6
    'erect',            # 7
    'prepare_rebar',    # 8
    'transport',        # 9

    # formwork
    'install',          # 10
    'prepare_formwork', # 11

    # concrete
    'pour',             # 12
    'finish',           # 13

    # equipment         
    'use',              # 14
    'carry',            # 15

    # all
    'inspect',          # 16
    'no_interaction',   # 17
]
# new_action_classes = [
#     # rebar
#     'tie',              # 0
#     'erect',            # 1
#     'prepare_rebar',    # 2
#     'transport',        # 3

#     # equipment         
#     'use',              # 4
#     'carry',            # 5

#     # all
#     'inspect',          # 6
#     'no interaction',   # 7
# ]
# new_action_classes = [
#     # all
#     'inspect',          # 0
    
#     # rebar
#     'prepare_rebar',    # 1
#     'erect',            # 2
#     'tie',              # 3
# ]
new_action_classes = [
    # rebar
    'tie',              # 0
    'erect',            # 1
    'prepare_rebar',    # 2
    'transport',        # 3

    # equipment         
    'use',              # 4
    'carry',            # 5

    # all
    'inspect',          # 6
    'no_interaction',   # 7
]
num_classes = len(new_action_classes)
# num_classes = len(action_classes)

# Non-Windowed
train_features_dirs = [
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0085_full_MP4_anno_for_labelling_done_yoga_full_temporal_3s/features'),
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0083_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'), 
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0087_full_MP4_anno_for_labelling_done_arga_full_temporal_3s/features'),
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0078_full_MP4_anno_for_labelling_done_anne_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0090_full_MP4_anno_for_labelling_rizky_full_temporal_3s/features'),
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0099_full_MP4_anno_for_labelling_done_arga_full_temporal_3s/features'),
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0101_full_MP4_anno_for_labelling_done_faridz_full_temporal_3s/features'),
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0098_full_MP4_anno_for_labelling_done_akbar_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0104_full_MP4_anno_for_labelling_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0105_full_MP4_anno_for_labelling_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0106_full_MP4_anno_for_labelling_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0110_full_MP4_anno_for_labelling_full_temporal_3s/features'),
    
    # Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'),
    
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0085_full_MP4_anno_for_labelling_done_yoga_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0083_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'), 
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0087_full_MP4_anno_for_labelling_done_arga_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0078_full_MP4_anno_for_labelling_done_anne_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0099_full_MP4_anno_for_labelling_done_arga_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0101_full_MP4_anno_for_labelling_done_faridz_full_temporal_3s/features'),
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0098_full_MP4_anno_for_labelling_done_akbar_full_temporal_3s/features'),
    
    Path('/root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'),
]

# val_features_dirs = [
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'),
# ]

# test_features_dirs = [
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data/C0074_full_MP4_anno_for_labelling_done_ray_full_temporal_3s/features'),   
# ]

# Windowed
# train_features_dirs = [
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0085_full_MP4_anno_for_labelling_done_yoga_full_temporal_3s/features'),
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0083_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'), 
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0087_full_MP4_anno_for_labelling_done_arga_full_temporal_3s/features'),
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0078_full_MP4_anno_for_labelling_done_anne_full_temporal_3s/features'),
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0090_full_MP4_anno_for_labelling_rizky_full_temporal_3s/features'),
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0099_full_MP4_anno_for_labelling_done_arga_full_temporal_3s/features'),
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0101_full_MP4_anno_for_labelling_done_faridz_full_temporal_3s/features'),
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0098_full_MP4_anno_for_labelling_done_akbar_full_temporal_3s/features'),
# ]

# val_features_dirs = [
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features'),
# ]

# test_features_dirs = [
#     Path('/root/vs-gats-plaster/deepsort/hiergat_data_windowed/C0074_full_MP4_anno_for_labelling_done_ray_full_temporal_3s/features'),   
# ]
# Out:
# Log directory: /root/workspace/HierGAT-Custom/outputs_hiergat/custom/hs512_e10_bs32_lr0.0001_0.5_20251208125912

# %%
# Data
def get_features_dirs_df(features_dirs):
    feature_dirs_dict = []
    for dirs in features_dirs:
        print("dirs:", dirs)
        for dir in dirs.iterdir():
            print(dir)
            action_label_str = str(dir).rsplit('_action_')[-1]
            is_interpolated = 0
            if '_interp' in action_label_str:
                action_label_str = action_label_str.replace('_interp', '')
                is_interpolated = 1
            action_label = int(action_label_str)
            action_class = action_classes[action_label]
            if 'new_action_classes' in globals():
                try:
                    action_label = new_action_classes.index(action_class) # type: ignore
                except ValueError:
                    action_label = -1
                    
            item = {
                'base_dir': str(dirs),
                'dir': str(dir),
                'action_label': action_label,
                # 'new_action_label': new_action_label,
                'is_interpolated': is_interpolated,
            }
            
            # if dirs in x:
            #     print(item)
            
            feature_dirs_dict.append(item)
        
    feature_dirs_df = pd.DataFrame(feature_dirs_dict)
    feature_dirs_df = feature_dirs_df[feature_dirs_df['action_label'] != -1] # remove rows where action_label == -1
    # feature_dirs_df = feature_dirs_df[feature_dirs_df['action_label'] > 5]   # keep rows with humna-to-object actions only
    return feature_dirs_df

feature_dirs_df = get_features_dirs_df(train_features_dirs)

print("Action label counts:")
print(feature_dirs_df['action_label'].value_counts())
# Out:
# dirs: /root/vs-gats-plaster/deepsort/hiergat_data/C0090_full_MP4_anno_for_labelling_rizky_full_temporal_3s/features
# dirs: /root/vs-gats-plaster/deepsort/hiergat_data/C0104_full_MP4_anno_for_labelling_full_temporal_3s/features
# dirs: /root/vs-gats-plaster/deepsort/hiergat_data/C0105_full_MP4_anno_for_labelling_full_temporal_3s/features
# dirs: /root/vs-gats-plaster/deepsort/hiergat_data/C0106_full_MP4_anno_for_labelling_full_temporal_3s/features
# dirs: /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8003_7826_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_6868_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_12204_12381_connection_6657_6992_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15265_15442_connection_8957_8957_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1967_2144_connection_969_15_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8597_8774_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8180_7826_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15043_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15220_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3588_3765_connection_1387_1601_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14787_14964_connection_8198_8198_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_276_276_connection_15_15_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1879_2056_connection_969_15_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8789_8612_connection_3216_3732_action_10
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7826_7826_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1473_1650_connection_3_3_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16518_16695_connection_9632_9492_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7399_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8410_8410_connection_3216_3216_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14512_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3780_3426_connection_1387_1387_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_99_276_connection_15_15_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8435_8612_connection_3216_3732_action_10
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1485_1662_connection_3_3_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_453_276_connection_15_15_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15907_16084_connection_8957_9325_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16209_16386_connection_8198_9492_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15883_16060_connection_8957_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14523_14700_connection_8198_8476_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2746_2923_connection_1199_969_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_9178_8647_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2724_2901_connection_1199_1199_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2056_2056_connection_969_15_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2106_2283_connection_969_15_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3249_3426_connection_1387_1387_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15864_16041_connection_8957_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8824_8647_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_9001_8647_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7045_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16502_16679_connection_9632_9492_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14689_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16655_16832_connection_9713_9728_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_6514_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15876_16053_connection_8957_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7882_8059_connection_3216_4435_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_4045_4222_connection_1387_1925_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3957_3426_connection_1387_1387_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14335_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15797_15974_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1650_1650_connection_3_3_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7576_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_4486_4663_connection_1387_2206_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8357_7826_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3603_3426_connection_1387_1387_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7753_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2100_2277_connection_969_15_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3765_3765_connection_1387_1601_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7608_7785_connection_3216_4260_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1997_2174_connection_969_15_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14880_15057_connection_8198_8198_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3593_3770_connection_1387_1601_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7612_7789_connection_3216_4260_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3596_3773_connection_1387_1601_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_9143_8612_connection_3216_3732_action_10
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_11730_11907_connection_6657_6761_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8612_8612_connection_3216_3732_action_10
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14964_14964_connection_8198_8198_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15619_15442_connection_8957_8957_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3773_3773_connection_1387_1601_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_9448_9625_connection_3216_5462_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16527_16704_connection_9632_9492_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1839_1662_connection_3_3_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16558_16735_connection_9632_9492_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3747_3924_connection_1387_1601_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_6691_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8966_8612_connection_3216_3732_action_10
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16231_16408_connection_8198_9492_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16526_16703_connection_9632_9492_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15442_15442_connection_8957_8957_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8073_8250_connection_3216_4435_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2901_2901_connection_1199_1199_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14158_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2718_2895_connection_969_1199_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2808_2985_connection_1237_1237_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8534_7826_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_767_944_connection_136_136_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3770_3770_connection_1387_1601_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2174_2174_connection_969_15_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15889_16066_connection_8198_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8764_8410_connection_3216_3216_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1441_1618_connection_3_3_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1662_1662_connection_3_3_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8470_8647_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14866_14335_connection_8198_8198_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_1827_1650_connection_3_3_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_14521_14698_connection_8198_8476_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16060_16237_connection_8198_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2716_2893_connection_1199_969_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15057_15057_connection_8198_8198_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3661_3838_connection_1387_1601_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2985_2985_connection_1237_1237_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8587_8410_connection_3216_3216_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8647_8647_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_3426_3426_connection_1387_1387_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_6337_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_16495_16672_connection_9632_9492_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_4047_4224_connection_1387_1925_action_16
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7649_7826_connection_3216_3732_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15878_16055_connection_8198_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_604_781_connection_136_136_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_8233_8410_connection_3216_3216_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_15935_16112_connection_8198_9325_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_7222_6514_connection_3216_3216_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s/features/duration_177_range_2561_2738_connection_969_969_action_9
# dirs: /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13277_13454_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15807_15984_connection_10749_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7634_7811_connection_4338_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8174_7289_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14675_14498_connection_9753_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15563_15740_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13260_13260_connection_8669_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7350_7350_connection_4338_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2021_2198_connection_1209_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13790_13967_connection_9275_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10347_10524_connection_6347_5577_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_9750_9927_connection_6220_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14682_13974_connection_9275_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6535_5827_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1845_1668_connection_914_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14976_15153_connection_10008_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10801_10447_connection_6643_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4527_4527_connection_2628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16322_15437_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6728_6197_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2616_2085_connection_745_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7289_7289_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1528_1705_connection_914_892_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16728_16728_connection_11217_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16484_16661_connection_8807_8807_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_9532_9532_connection_5638_5577_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15997_16174_connection_10578_10923_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6370_5839_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14634_14103_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14498_13967_connection_9275_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6679_6856_connection_4124_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_3827_3827_connection_2273_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2846_3023_connection_1814_328_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_758_227_connection_55_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16673_16673_connection_11196_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13668_13491_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16905_16728_connection_11217_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14353_13468_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_3746_3923_connection_2315_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_3555_3555_connection_2024_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1213_1390_connection_745_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7466_7289_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14756_14756_connection_9920_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14311_14134_connection_9275_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15032_15032_connection_10008_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_975_798_connection_328_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16300_15592_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_245_245_connection_55_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1632_924_connection_328_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4956_4779_connection_2855_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10550_10550_connection_6643_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15184_15361_connection_10306_10351_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5882_5882_connection_3382_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4629_4452_connection_2628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15748_13447_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4113_4290_connection_2436_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6302_5948_connection_3382_2935_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_17244_17244_connection_11467_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4269_4446_connection_2628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12352_12175_connection_7848_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4514_4514_connection_2628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8081_8258_connection_4929_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14188_14365_connection_9628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13014_13014_connection_8426_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12292_12292_connection_7848_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13547_13724_connection_8982_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_9157_9157_connection_5638_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16756_16756_connection_11196_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2610_2610_connection_745_1542_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4570_4747_connection_2855_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15756_15933_connection_10578_10728_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12413_12590_connection_7848_7526_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7387_7387_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15790_15436_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12386_12209_connection_7848_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4402_4579_connection_2628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7797_7266_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_3568_3745_connection_2085_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_17523_17700_connection_11957_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6782_5897_connection_3441_3441_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_3647_3824_connection_2277_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15011_14834_connection_10008_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4826_4472_connection_2663_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6724_5839_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_3667_3844_connection_2273_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_826_1003_connection_483_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5986_5809_connection_3382_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6016_5839_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5778_5955_connection_3526_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10056_10233_connection_6469_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4756_4579_connection_2628_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10187_10364_connection_6558_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8816_8462_connection_5023_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16083_16083_connection_10578_10856_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10232_9878_connection_6220_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15946_15592_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7734_7557_connection_4479_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13249_13426_connection_8721_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14107_14284_connection_9349_9297_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15189_14835_connection_10008_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7728_7905_connection_4666_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5254_5431_connection_3241_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13018_13195_connection_8578_8295_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4699_4876_connection_2920_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_17021_16844_connection_11217_8807_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14675_13967_connection_9275_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8940_8409_connection_5023_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14657_14834_connection_10008_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_9939_9939_connection_6220_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15220_15397_connection_10394_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16526_16703_connection_11217_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2053_2230_connection_1209_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14560_14737_connection_9939_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8440_8263_connection_4881_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1567_1390_connection_745_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2420_2597_connection_630_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12310_11779_connection_7526_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13967_13967_connection_9267_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10293_9939_connection_6220_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5187_5187_connection_3126_2944_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15650_15650_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2198_2375_connection_1335_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8805_8628_connection_5023_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14034_13680_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15569_15746_connection_8807_8807_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8600_8777_connection_5275_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8495_8672_connection_5179_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8207_8384_connection_4946_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5982_5982_connection_3382_2935_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13725_13725_connection_8982_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14726_14726_connection_9920_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_11085_11262_connection_6643_7127_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15433_15610_connection_10578_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4332_4509_connection_2663_2663_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16398_16575_connection_11127_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5839_5839_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8376_8376_connection_4881_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1384_1384_connection_745_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2967_3144_connection_745_1776_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4346_4346_connection_2566_2315_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15369_15546_connection_10545_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1931_1400_connection_745_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_188_365_connection_55_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10722_10545_connection_6220_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_17413_17413_connection_11739_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16831_15592_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7637_7637_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16579_16756_connection_11196_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1149_795_connection_328_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_17228_17405_connection_11739_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6076_5899_connection_3382_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_6534_5826_connection_3441_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14401_14578_connection_9753_9753_action_14
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_5897_5897_connection_3441_3441_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_9519_9519_connection_5638_5577_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12158_11804_connection_7526_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_7305_7305_connection_3441_3441_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_4649_4472_connection_2663_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13485_13662_connection_8982_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_12335_11804_connection_7526_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_8138_7607_connection_4318_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_13883_14060_connection_9275_8982_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1831_1831_connection_745_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_14884_13468_connection_8807_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15209_15032_connection_10008_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_2201_2378_connection_1335_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10368_10545_connection_6220_6643_action_9
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_16969_16792_connection_11217_8807_action_2
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_1396_865_connection_328_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_15791_15437_connection_10474_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_10863_10509_connection_6643_10_action_7
# /root/vs-gats-plaster/deepsort/hiergat_data/C0109_full_MP4_anno_for_labelling_full_temporal_3s/features/duration_177_range_580_226_connection_55_10_action_7
# ...
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3614.0_2729.0_connection_911.0_911.0_action_8
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2650.0_2473.0_connection_869.0_867.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_430.0_253.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3297.0_3474.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_0.0_177.0_connection_2.0_8.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4780.0_4780.0_connection_2096.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_780.0_780.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3828.0_3474.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1344.0_1521.0_connection_276.0_458.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_838.0_838.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1593.0_177.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1793.0_1439.0_connection_276.0_276.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2444.0_2267.0_connection_824.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4150.0_4327.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_184.0_184.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2800.0_2623.0_connection_869.0_867.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1233.0_1410.0_connection_276.0_458.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4152.0_4329.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3671.0_3848.0_connection_911.0_911.0_action_6
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4418.0_3710.0_connection_1073.0_1073.0_action_6
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_873.0_342.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4628.0_4805.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1497.0_1320.0_connection_276.0_458.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_7.0_184.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1504.0_1504.0_connection_276.0_458.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4745.0_4391.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3797.0_3620.0_connection_1073.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_95.0_272.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4763.0_4763.0_connection_2096.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_177.0_177.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2495.0_2141.0_connection_276.0_760.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_165.0_342.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4715.0_4892.0_connection_2093.0_1902.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_661.0_838.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1320.0_1320.0_connection_276.0_458.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3999.0_3468.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_276.0_453.0_connection_3.0_3.0_action_6
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2642.0_1403.0_connection_276.0_276.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_532.0_178.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3822.0_3468.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2090.0_2267.0_connection_824.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4504.0_4327.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_453.0_453.0_connection_7.0_3.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4713.0_3474.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1311.0_780.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_723.0_546.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1.0_178.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3135.0_3135.0_connection_867.0_869.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2457.0_2280.0_connection_824.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2676.0_2676.0_connection_911.0_911.0_action_6
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3887.0_3710.0_connection_1073.0_1073.0_action_6
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1494.0_1494.0_connection_276.0_458.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3716.0_3539.0_connection_1073.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4890.0_3474.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_984.0_453.0_connection_7.0_3.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3968.0_2729.0_connection_911.0_911.0_action_8
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2671.0_2317.0_connection_824.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_354.0_177.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2288.0_1403.0_connection_276.0_276.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1015.0_838.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_538.0_184.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_643.0_643.0_connection_153.0_153.0_action_3
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_603.0_780.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1271.0_209.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1428.0_543.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4530.0_3468.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3199.0_3199.0_connection_911.0_911.0_action_6
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4706.0_4706.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4182.0_3474.0_connection_1073.0_1404.0_action_0
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1338.0_453.0_connection_7.0_3.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2280.0_2280.0_connection_824.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_520.0_520.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4984.0_4807.0_connection_2096.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4153.0_4330.0_connection_1819.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2729.0_2729.0_connection_911.0_911.0_action_8
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_1580.0_1403.0_connection_276.0_276.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4927.0_4750.0_connection_2096.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_519.0_342.0_connection_3.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4553.0_4730.0_connection_2096.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_807.0_453.0_connection_7.0_3.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2465.0_1403.0_connection_276.0_276.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_4111.0_4288.0_connection_1468.0_1286.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_740.0_209.0_connection_7.0_10.0_action_17
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2665.0_2665.0_connection_867.0_869.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_2488.0_2665.0_connection_867.0_869.0_action_1
# /root/vs-gats-plaster/deepsort/hiergat_data_v2511/C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s/features/duration_177_range_3474.0_3474.0_connection_1073.0_1404.0_action_0
# Action label counts:
# action_label
# 1    1582
# 7    1028
# 0     951
# 2     544
# 6     163
# 4     130
# 3      88
# 5      36
# Name: count, dtype: int64

# %%
# def downsample_majority(df, label_col, majority_label, n_samples, seed):
#     majority_df = df[df[label_col] == majority_label]
#     others_df   = df[df[label_col] != majority_label]
#     majority_df_downsampled = majority_df.sample(n=n_samples, random_state=seed)
#     df_balanced = pd.concat([majority_df_downsampled, others_df])
#     df_balanced = df_balanced.sample(frac=1, random_state=seed).reset_index(drop=True) # shuffle
#     return df_balanced

# feature_dirs_df_balanced = downsample_majority(
#     feature_dirs_df,
#     label_col='action_label',
#     majority_label=new_action_classes.index('erect'),
#     n_samples=1028,
#     seed=seed
# )

# print("Action label value counts (balanced):")
# print(feature_dirs_df_balanced['action_label'].value_counts())

feature_dirs_df_balanced = feature_dirs_df

# %%
def stratified_split_with_minority(df, label_col, test_size, seed):
    # Identify minority and majority classes
    label_counts = df[label_col].value_counts()
    minority_labels = label_counts[label_counts < 2].index
    minority_df = df[df[label_col].isin(minority_labels)]
    others_df = df[~df[label_col].isin(minority_labels)]

    # Split only the majority classes
    train_df, test_df = train_test_split(
        others_df,
        test_size=test_size,
        stratify=others_df[label_col],
        random_state=seed
    )

    # Add back minority samples & shuffle
    train_df = pd.concat([train_df, minority_df]).sample(frac=1, random_state=seed).reset_index(drop=True)
    return train_df, test_df

train_df, val_test_df = stratified_split_with_minority(
    feature_dirs_df_balanced,
    label_col='action_label',
    test_size=val_fraction*2,
    seed=seed
)
val_df, test_df = stratified_split_with_minority(
    val_test_df,
    label_col='action_label',
    test_size=0.5,
    seed=seed
)

train_feature_dirs = train_df['dir'].tolist()
val_feature_dirs   = val_df['dir'].tolist()
test_feature_dirs  = test_df['dir'].tolist()

# %%
# Replace 'prepare_rebar' with 'prepare' in the dataframes' display column
train_df['action_label_name'] = train_df['action_label_name'].str.replace('prepare_rebar', 'prepare', regex=False)
val_df['action_label_name']   = val_df['action_label_name'].str.replace('prepare_rebar', 'prepare', regex=False)
test_df['action_label_name']  = test_df['action_label_name'].str.replace('prepare_rebar', 'prepare', regex=False)

# Optionally update the canonical list and mapping so future remapping uses the new name
new_action_classes = [c.replace('prepare_rebar', 'prepare') for c in new_action_classes]
action_classes_dict = {i: f'{i}. {action_class}' for i, action_class in enumerate(new_action_classes)}

# %%
# Sanity check the action class distribution of the training, validation, and testing sets
action_classes_dict = {i: f'{i}. {action_class}' for i, action_class in enumerate(new_action_classes)}
train_df['action_label_name'] = train_df['action_label'].map(action_classes_dict)
val_df['action_label_name'] = val_df['action_label'].map(action_classes_dict)
test_df['action_label_name'] = test_df['action_label'].map(action_classes_dict)

print("Training action class distribution:")
print(train_df['action_label_name'].value_counts().sort_index())
print()
print("Validation action class distribution:")
print(val_df['action_label_name'].value_counts().sort_index())
print()
print("Testing action class distribution:")
print(test_df['action_label_name'].value_counts().sort_index())
print()
# Out:
# Training action class distribution:
# action_label_name
# 0. tie                761
# 1. erect             1266
# 2. prepare            435
# 3. transport           70
# 4. use                104
# 5. carry               29
# 6. inspect            130
# 7. no_interaction     822
# Name: count, dtype: int64
#
# Validation action class distribution:
# action_label_name
# 0. tie                95
# 1. erect             158
# 2. prepare            54
# 3. transport           9
# 4. use                13
# 5. carry               4
# 6. inspect            16
# 7. no_interaction    103
# Name: count, dtype: int64
#
# Testing action class distribution:
# action_label_name
# 0. tie                95
# 1. erect             158
# 2. prepare            55
# 3. transport           9
# 4. use                13
# 5. carry               3
# 6. inspect            17
# 7. no_interaction    103
# Name: count, dtype: int64

# %%
len(train_features_dirs)
# Out:
# 15

# %%
for i, (base_dir, df_per_base_dir) in enumerate(train_df.groupby('base_dir')):
    video_name = base_dir.split('/')[-2]
    print(f"{i+1}. {video_name}")
    print(df_per_base_dir['action_label_name'].value_counts().sort_index())
    print()
# Out:
# 1. C0108_full_MP4_anno_for_labelling_fixed_full_temporal_3s
# action_label_name
# 1. erect        16
# 3. transport    16
# 4. use          29
# 6. inspect      13
# Name: count, dtype: int64
#
# 2. C0109_full_MP4_anno_for_labelling_full_temporal_3s
# action_label_name
# 1. erect        1237
# 3. transport      32
# 4. use            25
# Name: count, dtype: int64
#
# 3. C0110_full_MP4_anno_for_labelling_full_temporal_3s
# action_label_name
# 2. prepare_rebar    15
# 3. transport        21
# 4. use              23
# Name: count, dtype: int64
#
# 4. C0078_full_MP4_anno_for_labelling_done_anne_full_temporal_3s
# action_label_name
# 0. tie               98
# 7. no_interaction    53
# Name: count, dtype: int64
#
# 5. C0083_full_MP4_anno_for_labelling_done_putu_full_temporal_3s
# action_label_name
# 0. tie               196
# 1. erect               5
# 2. prepare_rebar      39
# 3. transport           1
# 4. use                 5
# 6. inspect             2
# 7. no_interaction     29
# Name: count, dtype: int64
#
# 6. C0085_full_MP4_anno_for_labelling_done_yoga_full_temporal_3s
# action_label_name
# 0. tie               159
# 2. prepare_rebar     152
# 4. use                21
# 7. no_interaction     63
# Name: count, dtype: int64
#
# 7. C0087_full_MP4_anno_for_labelling_done_arga_full_temporal_3s
# action_label_name
# 0. tie               163
# 5. carry               7
# 6. inspect           106
# 7. no_interaction    186
# Name: count, dtype: int64
#
# 8. C0098_full_MP4_anno_for_labelling_done_akbar_full_temporal_3s
# action_label_name
# 0. tie                1
# 1. erect              8
# 5. carry             17
# 7. no_interaction    71
# Name: count, dtype: int64
#
# 9. C0099_full_MP4_anno_for_labelling_done_arga_full_temporal_3s
# action_label_name
# 0. tie                 2
# 2. prepare_rebar     221
# 5. carry               5
# 6. inspect             5
# 7. no_interaction     21
# Name: count, dtype: int64
#
# 10. C0100_full_MP4_anno_for_labelling_done_putu_full_temporal_3s
# action_label_name
# 0. tie                20
# 2. prepare_rebar       8
# 4. use                 1
# 7. no_interaction    153
# Name: count, dtype: int64
#
# 11. C0101_full_MP4_anno_for_labelling_done_faridz_full_temporal_3s
# action_label_name
# 0. tie               122
# 6. inspect             4
# 7. no_interaction    246
# Name: count, dtype: int64

# %%
train_base_dirs = [base_dir for base_dir, _ in train_df.groupby('base_dir')]
x = list(set([str(d) for d in train_features_dirs]) - set(train_base_dirs))
x

# %%
train_data = create_data(train_feature_dirs, action_classes, new_action_classes if 'new_action_classes' in globals() else None) # type: ignore
val_data = create_data(val_feature_dirs, action_classes, new_action_classes if 'new_action_classes' in globals() else None)     # type: ignore
test_data = create_data(test_feature_dirs, action_classes, new_action_classes if 'new_action_classes' in globals() else None)   # type: ignore
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train_data = create_data(train_feature_dirs, action_classes, new_action_classes if 'new_action_classes' in globals() else None) # type: ignore
#       2 val_data = create_data(val_feature_dirs, action_classes, new_action_classes if 'new_action_classes' in globals() else None)     # type: ignore
#       3 test_data = create_data(test_feature_dirs, action_classes, new_action_classes if 'new_action_classes' in globals() else None)   # type: ignore
#
# File ~/workspace/HierGAT-Custom/vhoi/data_loading_custom.py:31, in create_data(feature_dirs, action_classes, new_action_classes, downsampling, test_data)
#      28 feature_dir = Path(feature_dir)
#      30 # Load and store human (subject) features
# ---> 31 subject_visual_features = np.load(feature_dir / 'subject_visual_features.npy')
#      32 subject_boxes = np.load(feature_dir / 'subject_boxes.npy')
#      33 # subject_poses = np.zeros((subject_visual_features.shape[0], 17, 2))
#
# File ~/anaconda3/envs/py39_torch271/lib/python3.9/site-packages/numpy/lib/npyio.py:456, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453         return format.open_memmap(file, mode=mmap_mode,
#     454                                   max_header_size=max_header_size)
#     455     else:
# --> 456         return format.read_array(fid, allow_pickle=allow_pickle,
#     457                                  pickle_kwargs=pickle_kwargs,
#     458                                  max_header_size=max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
#
# File ~/anaconda3/envs/py39_torch271/lib/python3.9/site-packages/numpy/lib/format.py:809, in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     806 else:
#     807     if isfileobj(fp):
#     808         # We can use the fast fromfile() function.
# --> 809         array = numpy.fromfile(fp, dtype=dtype, count=count)
#     810     else:
#     811         # This is not a real file. We have to read it the
#     812         # memory-intensive way.
#    (...)
#     820         # not correctly instantiate zero-width string dtypes; see
#     821         # https://github.com/numpy/numpy/pull/6430
#     822         array = numpy.ndarray(count, dtype=dtype)
#
# KeyboardInterrupt:

# %%
train_loader, scalers, _ = create_data_loader(
    *train_data, 
    model_name, 
    batch_size=batch_size, 
    shuffle=True,
    scaling_strategy=scaling_strategy, 
    sigma=sigma,
    downsampling=downsampling,
)
val_loader, _, _ = create_data_loader(
    *val_data, 
    model_name, 
    batch_size=len(val_data[0]),
    shuffle=False, 
    scalers=scalers, 
    sigma=sigma, 
    downsampling=downsampling,
)
test_loader, _, _ = create_data_loader(
    *test_data, 
    model_name, 
    batch_size=len(test_data[0]),
    shuffle=False, 
    scalers=scalers, 
    sigma=sigma, 
    downsampling=downsampling,
)
input_size = input_size_from_data_loader(train_loader, model_name, model_input_type)
data_info = {'input_size': input_size}

# %%
# Model
model_creation_args = cfg.models.parameters
model_creation_args = {**data_info, **model_creation_args.__dict__}
dataset_name = cfg.data.name
model_creation_args['num_classes'] = (num_classes, None)
device = 'cuda' if torch.cuda.is_available() and cfg.resources.use_gpu else 'cpu'
model = TGGCN(feat_dim=1024, **model_creation_args).to(device)
if misc_dict.get('pretrained', False) and misc_dict.get('pretrained_path') is not None:
    state_dict = load_model_weights(misc_dict['pretrained_path'])
    model.load_state_dict(state_dict, strict=False)
params = model.parameters()
optimizer = torch.optim.Adam(params, lr=cfg.models.optimization.learning_rate)
criterion, loss_names = select_loss(model_name, model_input_type, dataset_name, cfg=cfg)
mtll_model = None
if misc_dict.get('multi_task_loss_learner', False):
    loss_types = select_loss_types(model_name, dataset_name, cfg=cfg)
    mask = select_loss_learning_mask(model_name, dataset_name, cfg=cfg)
    mtll_model = MultiTaskLossLearner(loss_types=loss_types, mask=mask).to(device)
    optimizer.add_param_group({'params': mtll_model.parameters()})
# Some config + model training
tensorboard_log_dir = cfg.models.logging.root_log_dir
checkpoint_name = cfg.models.logging.checkpoint_name
fetch_model_data = select_model_data_fetcher(model_name, model_input_type,
                                             dataset_name=dataset_name, **{**misc_dict, **cfg.models.parameters.__dict__})
feed_model_data = select_model_data_feeder(model_name, model_input_type, dataset_name=dataset_name, **misc_dict)
num_main_losses = decide_num_main_losses(model_name, dataset_name, {**misc_dict, **cfg.models.parameters.__dict__})
checkpoint = train(
    model, 
    train_loader, 
    optimizer, 
    criterion, 
    cfg.models.optimization.epochs, 
    device, 
    loss_names,
    clip_gradient_at=cfg.models.optimization.clip_gradient_at,
    fetch_model_data=fetch_model_data, feed_model_data=feed_model_data,
    val_loader=val_loader, 
    mtll_model=mtll_model, 
    num_main_losses=num_main_losses,
    tensorboard_log_dir=tensorboard_log_dir, 
    checkpoint_name=checkpoint_name,
)
# Logging
if cfg.models.logging.log_dir is not None:
    log_dir = cfg.models.logging.log_dir
    checkpoint['scalers'] = scalers
    save_checkpoint(log_dir, checkpoint, checkpoint_name=checkpoint_name, include_timestamp=False)

# %% [markdown]
# # Predict

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

from predict import match_shape, match_att_shape

inspect_model = False

model.eval();

# %%
outputs, targets, attentions = [], [], []
for i, dataset in enumerate(test_loader):
    data, target = fetch_model_data(dataset, device=device)
    with torch.no_grad():
        output = feed_model_data(model, data)
    if inspect_model:
        output, attention_scores = output
        attention_scores = [att_score[:, 0] for att_score in attention_scores]
    if num_main_losses is not None:
        output = output[-num_main_losses:]
        target = target[-num_main_losses:]
    if downsampling > 1:
        for i, (out, tgt) in enumerate(zip(output, target)):
            if out.ndim != 4:
                raise RuntimeError(f'Number of dimensions for output is {out.ndim}')
            out = torch.repeat_interleave(out, repeats=downsampling, dim=-2)
            out = match_shape(out, tgt)
            output[i] = out
        if inspect_model:
            a_target = target[0]
            attention_scores = [torch.repeat_interleave(att_score, repeats=downsampling, dim=-2)
                                for att_score in attention_scores]
            attention_scores = [match_att_shape(att_score, a_target) for att_score in attention_scores]
            attentions.append(attention_scores)
    outputs += output
    targets += target

# %%
# ORIGINAL
# y_pred = torch.argmax(outputs[0], dim=1)
# y_pred = y_pred.squeeze(-1).mode(dim=1).values.cpu().numpy()

# CUSTOM
y_pred = torch.argmax(outputs[0], dim=1).cpu().numpy()

y_true = targets[0].squeeze(-1).mode(dim=1).values.cpu().numpy()

# %%
acc = accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)

print("Accuracy:", acc)
print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)

# %%
# ticklabels = action_classes
ticklabels = new_action_classes
if 'new_action_classes' in globals() and isinstance(new_action_classes, (list, tuple)): # type: ignore
    y_true = [ticklabels.index(new_action_classes[y]) for y in y_true]              # type: ignore
    y_pred = [ticklabels.index(new_action_classes[y]) for y in y_pred]              # type: ignore
    
cm = confusion_matrix(y_true, y_pred, labels=list(range(len(ticklabels))))

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=ticklabels, yticklabels=ticklabels)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
